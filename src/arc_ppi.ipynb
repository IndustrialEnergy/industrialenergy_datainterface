# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %% [markdown]
# ### Adjust impcost to current year value

# %% [markdown]
# #### Import clean ppi and iac datasets

# %%
# ------- define paths -------
relative_path = Path('../data/intermediate_data/') # define relative path
absolute_path = relative_path.resolve() # get absolute path


# ------- import data -------
assess_df = pd.read_csv(absolute_path/'iac_assess_tidy.csv') # import IAC assess dataset
recc_df = pd.read_csv(absolute_path/'iac_recc_tidy.csv') # import IAC recc dataset
ppi_df = pd.read_csv(absolute_path/'ppi_tidy.csv') # import ppi dataset

# %%
# Merge the PPI dataframe with the RECC dataframe on the arc2 and year columns
recc_ppi_df = pd.merge(ppi_df, recc_df[['arc2', 'superid', 'fy', 'impcost']], 
        left_on=['arc2','year'],
        right_on=['arc2','fy'],
        how='left'
    )

# # drop unused columns
recc_ppi_df = recc_ppi_df.dropna(subset=['superid', 'fy','impcost'], how='all')
recc_ppi_df = recc_ppi_df.dropna(subset=['impcost'], how='all') # exclude rows where impcost = NA
recc_ppi_df.drop_duplicates(inplace = True)
recc_ppi_df.drop(columns=['fy'], inplace=True)

# %%
# test
filtered = recc_ppi_df[recc_ppi_df['arc2']==2.1111]
print(filtered.count()) # should be 9 rows
filtered
# Out:
# arc2           9
# description    9
# series_id      9
# industry       9
# product        9
# year           9
# ppi            9
# superid        9
# impcost        9
# dtype: int64
#           arc2                             description        series_id  \
# 129119  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 148410  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 148414  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 159369  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 159373  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 159377  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 159381  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 159385  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 198531  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
#
#                                        industry  \
# 129119  Industrial process variable instruments
# 148410  Industrial process variable instruments
# 148414  Industrial process variable instruments
# 159369  Industrial process variable instruments
# 159373  Industrial process variable instruments
# 159377  Industrial process variable instruments
# 159381  Industrial process variable instruments
# 159385  Industrial process variable instruments
# 198531  Industrial process variable instruments
#
#                                         product  year    ppi   superid  \
# 129119  Industrial process variable instruments  2001  154.3  NC022707
# 148410  Industrial process variable instruments  2003  160.2  GT076008
# 148414  Industrial process variable instruments  2003  160.2  GT076310
# 159369  Industrial process variable instruments  2004  163.6  GT077806
# 159373  Industrial process variable instruments  2004  163.6  GT078012
# 159377  Industrial process variable instruments  2004  163.6  GT078410
# 159381  Industrial process variable instruments  2004  163.6  GT079208
# 159385  Industrial process variable instruments  2004  163.6  IA034003
# 198531  Industrial process variable instruments  2008  186.1  OR052903
#
#         impcost
# 129119   7500.0
# 148410  13200.0
# 148414   5823.0
# 159369  13000.0
# 159373    800.0
# 159377  29000.0
# 159381  32100.0
# 159385   4940.0
# 198531   1000.0

# %%
# set a reference_year
reference_year = 2018

# create a dataframe with ppi values in a reference year
ppi_ref_year_df = ppi_df[ppi_df['year']==2018]
ppi_ref_year_df = ppi_ref_year_df[['arc2', 'year', 'ppi']].rename(columns={'year': 'reference_year', 'ppi': 'reference_ppi'})

# add reference_year and reference year ppi values to recc_ppi_df
recc_ppi_df = pd.merge(recc_ppi_df,ppi_ref_year_df[['arc2','reference_year','reference_ppi']],
                       on='arc2',
                       how='left')

# Calculate impcost in a reference_year
recc_ppi_df['ref_year_impcost'] = recc_ppi_df['impcost'] * (recc_ppi_df['reference_ppi'] / recc_ppi_df['ppi'])

# %%
# test
filtered = recc_ppi_df[recc_ppi_df['arc2']==2.1111]
print(filtered['arc2'].count()) # should be 9 rows
filtered
# Out:
# 9
#          arc2                             description        series_id  \
# 25874  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 29885  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 29886  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 32145  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 32146  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 32147  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 32148  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 32149  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
# 40326  2.1111  CONTROL PRESSURE ON STEAMER OPERATIONS  PCU334513334513
#
#                                       industry  \
# 25874  Industrial process variable instruments
# 29885  Industrial process variable instruments
# 29886  Industrial process variable instruments
# 32145  Industrial process variable instruments
# 32146  Industrial process variable instruments
# 32147  Industrial process variable instruments
# 32148  Industrial process variable instruments
# 32149  Industrial process variable instruments
# 40326  Industrial process variable instruments
#
#                                        product  year    ppi   superid  \
# 25874  Industrial process variable instruments  2001  154.3  NC022707
# 29885  Industrial process variable instruments  2003  160.2  GT076008
# 29886  Industrial process variable instruments  2003  160.2  GT076310
# 32145  Industrial process variable instruments  2004  163.6  GT077806
# 32146  Industrial process variable instruments  2004  163.6  GT078012
# 32147  Industrial process variable instruments  2004  163.6  GT078410
# 32148  Industrial process variable instruments  2004  163.6  GT079208
# 32149  Industrial process variable instruments  2004  163.6  IA034003
# 40326  Industrial process variable instruments  2008  186.1  OR052903
#
#        impcost  reference_year  reference_ppi  ref_year_impcost
# 25874   7500.0            2018          221.7      10776.085548
# 29885  13200.0            2018          221.7      18267.415730
# 29886   5823.0            2018          221.7       8058.421348
# 32145  13000.0            2018          221.7      17616.748166
# 32146    800.0            2018          221.7       1084.107579
# 32147  29000.0            2018          221.7      39298.899756
# 32148  32100.0            2018          221.7      43499.816626
# 32149   4940.0            2018          221.7       6694.364303
# 40326   1000.0            2018          221.7       1191.295003

# %%
# integrate adjusted impcost into recc dataset
recc_df = pd.merge(recc_df,recc_ppi_df[['superid','ref_year_impcost']],
                   on='superid',
                   how='left')

# move ref_year_impcost column after impcost column
index = recc_df.columns.get_loc('impcost') + 1
recc_df.insert(index, 'ref_year_impcost', recc_df.pop('ref_year_impcost'))

# %%
# test
recc_OR052903 = recc_df[recc_df['superid']=='OR052903']
print(recc_OR052903['superid'].count()) # expected 4 rows

recc_2_1111 = recc_df[recc_df['arc2']==2.1111]
print(recc_2_1111['arc2'].count()) # expected 76 rows
recc_df
# Out:
# 4
# 76
#          superid      id  ar_number  appcode    arc2 impstatus  impcost  \
# 0       AM000101  AM0001          1      NaN  2.8114         N  15000.0
# 1       AM000101  AM0001          1      NaN  2.8114         N  15000.0
# 2       AM000101  AM0001          1      NaN  2.8114         N  15000.0
# 3       AM000101  AM0001          1      NaN  2.8114         N  15000.0
# 4       AM000102  AM0001          2      NaN  2.7142         N    189.0
# ...          ...     ...        ...      ...     ...       ...      ...
# 652595  WV067708  WV0677          8      NaN  2.4239       NaN    540.0
# 652596  WV067709  WV0677          9      NaN  2.2511       NaN    446.0
# 652597  WV067709  WV0677          9      NaN  2.2511       NaN    446.0
# 652598  WV067709  WV0677          9      NaN  2.2511       NaN    446.0
# 652599  WV067709  WV0677          9      NaN  2.2511       NaN    446.0
#
#         ref_year_impcost source_rank sourccode  conserved  sourconsv   saved  \
# 0                15000.0  PSOURCCODE        EC        NaN        NaN  1828.0
# 1                15000.0  SSOURCCODE       NaN        NaN        NaN     NaN
# 2                15000.0  TSOURCCODE       NaN        NaN        NaN     NaN
# 3                15000.0  QSOURCCODE       NaN        NaN        NaN     NaN
# 4                    NaN  PSOURCCODE        EC     7034.0       72.0   663.0
# ...                  ...         ...       ...        ...        ...     ...
# 652595               NaN  QSOURCCODE       NaN        NaN        NaN     NaN
# 652596               NaN  PSOURCCODE        E2       69.0        NaN   290.0
# 652597               NaN  SSOURCCODE       NaN        NaN        NaN     NaN
# 652598               NaN  TSOURCCODE       NaN        NaN        NaN     NaN
# 652599               NaN  QSOURCCODE       NaN        NaN        NaN     NaN
#
#        rebate incremntal    fy  ic_capital  ic_other   payback bptool
# 0           N          N  1987         NaN       NaN  8.205689    NaN
# 1           N          N  1987         NaN       NaN  8.205689    NaN
# 2           N          N  1987         NaN       NaN  8.205689    NaN
# 3           N          N  1987         NaN       NaN  8.205689    NaN
# 4           N          N  1987         NaN       NaN  0.285068    NaN
# ...       ...        ...   ...         ...       ...       ...    ...
# 652595      N          N  2025       400.0     140.0       NaN    AM+
# 652596      N          N  2025       330.0     116.0       NaN   SSTS
# 652597      N          N  2025       330.0     116.0       NaN   SSTS
# 652598      N          N  2025       330.0     116.0       NaN   SSTS
# 652599      N          N  2025       330.0     116.0       NaN   SSTS
#
# [652600 rows x 20 columns]

# %% [markdown]
# ### Save ppi recc integrated data

# %%
recc_df.to_csv("../data/intermediate_data/recc_ppi.csv", index=False)
